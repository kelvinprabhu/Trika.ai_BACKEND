# %%
import requests

url = "http://localhost:3000/api/user/complete-info"
params = {"email": "kelvinprabhu2071@gmail.com"}

response = requests.get(url, params=params)
print(response.json())
# Out:
# {'success': True, 'data': {'user': {'id': '688b14a0b659a7805cfc784c', 'firstName': 'kelvin', 'lastName': 'prabhu', 'email': 'kelvinprabhu2071@gmail.com', 'personalInfo': {'age': '24', 'gender': 'male', 'height': '175', 'weight': '83', 'activityLevel': 'intense'}, 'fitnessGoals': {'primaryGoal': 'build-muscle', 'fitnessLevel': 'intermediate', 'workoutFrequency': '3-4', 'preferredWorkouts': ['cardio', 'strength', 'hiit']}, 'preferences': {'notifications': True, 'dataSharing': False, 'newsletter': True, 'reminderTime': '09:00'}, 'onboardingCompleted': True, 'createdAt': '2025-07-31T07:00:48.326Z', 'updatedAt': '2025-07-31T07:01:46.503Z'}, 'habits': [{'_id': '68961cf62e9091a3e38018b2', 'userEmail': 'kelvinprabhu2071@gmail.com', 'name': 'Morning Work', 'icon': '🔥', 'category': 'mindfulness', 'streak': 1, 'bestStreak': 1, 'target': 1, 'frequency': 'custom', 'completedThisWeek': 1, 'totalWeeks': 1, 'weeklyData': [False, False, False, False, False, True, False], 'monthlyCompletion': 11, 'des
# ...
